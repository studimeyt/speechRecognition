# %% [markdown]
# <a href="https://colab.research.google.com/github/studimeyt/speechRecognition/blob/main/CNN_speech_recog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf

# %%
csv_file = str("/content/drive/MyDrive/MinorProject/voice.csv/voice.csv")
data = pd.read_csv(csv_file)

# %%
data
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
#              kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0      274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1      634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2     1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3        4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4        4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
# ...           ...       ...       ...  ...       ...       ...       ...
# 3163     6.630383  0.962934  0.763182  ...  0.131884  0.182790  0.083770
# 3164     2.503954  0.960716  0.709570  ...  0.116221  0.188980  0.034409
# 3165     6.604509  0.946854  0.654196  ...  0.142056  0.209918  0.039506
# 3166     5.388298  0.950436  0.675470  ...  0.143659  0.172375  0.034483
# 3167     5.769115  0.938829  0.601529  ...  0.165509  0.185607  0.062257
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx   label
# 0     0.275862  0.007812  0.007812  0.007812  0.000000  0.000000    male
# 1     0.250000  0.009014  0.007812  0.054688  0.046875  0.052632    male
# 2     0.271186  0.007990  0.007812  0.015625  0.007812  0.046512    male
# 3     0.250000  0.201497  0.007812  0.562500  0.554688  0.247119    male
# 4     0.266667  0.712812  0.007812  5.484375  5.476562  0.208274    male
# ...        ...       ...       ...       ...       ...       ...     ...
# 3163  0.262295  0.832899  0.007812  4.210938  4.203125  0.161929  female
# 3164  0.275862  0.909856  0.039062  3.679688  3.640625  0.277897  female
# 3165  0.275862  0.494271  0.007812  2.937500  2.929688  0.194759  female
# 3166  0.250000  0.791360  0.007812  3.593750  3.585938  0.311002  female
# 3167  0.271186  0.227022  0.007812  0.554688  0.546875  0.350000  female
#
# [3168 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
#  19  modindx   3168 non-null   float64
#  20  label     3168 non-null   object
# dtypes: float64(20), object(1)
# memory usage: 519.9+ KB

# %% [markdown]
# #Encoding Labels

# %%
label_encoder = LabelEncoder()

data['label'] = label_encoder.fit_transform(data['label'])

# %%
dict(enumerate(label_encoder.classes_))
# Out:
# {0: 'female', 1: 'male'}

# %%
data
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
#              kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0      274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1      634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2     1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3        4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4        4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
# ...           ...       ...       ...  ...       ...       ...       ...
# 3163     6.630383  0.962934  0.763182  ...  0.131884  0.182790  0.083770
# 3164     2.503954  0.960716  0.709570  ...  0.116221  0.188980  0.034409
# 3165     6.604509  0.946854  0.654196  ...  0.142056  0.209918  0.039506
# 3166     5.388298  0.950436  0.675470  ...  0.143659  0.172375  0.034483
# 3167     5.769115  0.938829  0.601529  ...  0.165509  0.185607  0.062257
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0     0.275862  0.007812  0.007812  0.007812  0.000000  0.000000      1
# 1     0.250000  0.009014  0.007812  0.054688  0.046875  0.052632      1
# 2     0.271186  0.007990  0.007812  0.015625  0.007812  0.046512      1
# 3     0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4     0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 3163  0.262295  0.832899  0.007812  4.210938  4.203125  0.161929      0
# 3164  0.275862  0.909856  0.039062  3.679688  3.640625  0.277897      0
# 3165  0.275862  0.494271  0.007812  2.937500  2.929688  0.194759      0
# 3166  0.250000  0.791360  0.007812  3.593750  3.585938  0.311002      0
# 3167  0.271186  0.227022  0.007812  0.554688  0.546875  0.350000      0
#
# [3168 rows x 21 columns]

# %% [markdown]
# #Splitting and Scaling

# %%
y = data['label'].copy()
X = data.drop('label', axis=1).copy()

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %% [markdown]
# #CNN

# %%
X = tf.keras.preprocessing.sequence.pad_sequences(X, dtype=np.float, maxlen=25, padding='post')
X = X.reshape(-1, 5, 5)
X = np.expand_dims(X, axis=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
X.shape
# Out:
# (3168, 5, 5, 1)

# %%
plt.figure(figsize=(12, 12))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(X[i]))
    plt.axis('on')
    
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
inputs = tf.keras.Input(shape=(X.shape[1], X.shape[2], X.shape[3]))

x = tf.keras.layers.Conv2D(16, 2, activation='relu')(inputs)
x = tf.keras.layers.MaxPooling2D()(x)

x = tf.keras.layers.Conv2D(32, 1, activation='relu')(x)
x = tf.keras.layers.MaxPooling2D()(x)

x = tf.keras.layers.Flatten()(x)

x = tf.keras.layers.Dense(64, activation='relu')(x)

outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 5, 5, 1)]         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 16)          80
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 32)          544
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,801
# Trainable params: 2,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc')
    ]
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.6427 - accuracy: 0.6407 - auc: 0.7912 - val_loss: 0.5625 - val_accuracy: 0.7860 - val_auc: 0.8784
# Epoch 2/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4494 - accuracy: 0.8613 - auc: 0.9265 - val_loss: 0.3638 - val_accuracy: 0.8964 - val_auc: 0.9464
# Epoch 3/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2943 - accuracy: 0.9086 - auc: 0.9619 - val_loss: 0.2626 - val_accuracy: 0.9234 - val_auc: 0.9660
# Epoch 4/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2323 - accuracy: 0.9171 - auc: 0.9703 - val_loss: 0.2294 - val_accuracy: 0.9234 - val_auc: 0.9712
# Epoch 5/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2015 - accuracy: 0.9239 - auc: 0.9759 - val_loss: 0.1954 - val_accuracy: 0.9324 - val_auc: 0.9784
# Epoch 6/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1817 - accuracy: 0.9351 - auc: 0.9803 - val_loss: 0.1830 - val_accuracy: 0.9324 - val_auc: 0.9808
# Epoch 7/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9442 - auc: 0.9836 - val_loss: 0.1743 - val_accuracy: 0.9324 - val_auc: 0.9828
# Epoch 8/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1568 - accuracy: 0.9447 - auc: 0.9850 - val_loss: 0.1630 - val_accuracy: 0.9347 - val_auc: 0.9835
# Epoch 9/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 0.9475 - auc: 0.9874 - val_loss: 0.1559 - val_accuracy: 0.9392 - val_auc: 0.9855
# Epoch 10/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9504 - auc: 0.9870 - val_loss: 0.1544 - val_accuracy: 0.9414 - val_auc: 0.9856
# Epoch 11/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1370 - accuracy: 0.9487 - auc: 0.9885 - val_loss: 0.1452 - val_accuracy: 0.9459 - val_auc: 0.9880
# Epoch 12/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1258 - accuracy: 0.9600 - auc: 0.9903 - val_loss: 0.1535 - val_accuracy: 0.9437 - val_auc: 0.9886
# Epoch 13/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9600 - auc: 0.9910 - val_loss: 0.1374 - val_accuracy: 0.9437 - val_auc: 0.9892
# Epoch 14/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9543 - auc: 0.9911 - val_loss: 0.1320 - val_accuracy: 0.9505 - val_auc: 0.9891
# Epoch 15/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9656 - auc: 0.9933 - val_loss: 0.1250 - val_accuracy: 0.9572 - val_auc: 0.9902
# Epoch 16/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9650 - auc: 0.9932 - val_loss: 0.1195 - val_accuracy: 0.9550 - val_auc: 0.9913
# Epoch 17/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9645 - auc: 0.9929 - val_loss: 0.1147 - val_accuracy: 0.9572 - val_auc: 0.9916
# Epoch 18/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1056 - accuracy: 0.9611 - auc: 0.9935 - val_loss: 0.1199 - val_accuracy: 0.9550 - val_auc: 0.9916
# Epoch 19/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9645 - auc: 0.9940 - val_loss: 0.1144 - val_accuracy: 0.9640 - val_auc: 0.9938
# Epoch 20/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9673 - auc: 0.9952 - val_loss: 0.1129 - val_accuracy: 0.9572 - val_auc: 0.9923
# Epoch 21/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0859 - accuracy: 0.9695 - auc: 0.9959 - val_loss: 0.1094 - val_accuracy: 0.9572 - val_auc: 0.9943
# Epoch 22/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9695 - auc: 0.9957 - val_loss: 0.1061 - val_accuracy: 0.9617 - val_auc: 0.9931
# Epoch 23/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0861 - accuracy: 0.9701 - auc: 0.9956 - val_loss: 0.0995 - val_accuracy: 0.9662 - val_auc: 0.9945
# Epoch 24/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0774 - accuracy: 0.9763 - auc: 0.9966 - val_loss: 0.0979 - val_accuracy: 0.9662 - val_auc: 0.9941
# Epoch 25/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0767 - accuracy: 0.9774 - auc: 0.9967 - val_loss: 0.0973 - val_accuracy: 0.9617 - val_auc: 0.9945
# Epoch 26/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9769 - auc: 0.9966 - val_loss: 0.1228 - val_accuracy: 0.9459 - val_auc: 0.9955
# Epoch 27/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 0.9780 - auc: 0.9974 - val_loss: 0.0905 - val_accuracy: 0.9662 - val_auc: 0.9957
# Epoch 28/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9769 - auc: 0.9973 - val_loss: 0.0994 - val_accuracy: 0.9595 - val_auc: 0.9952
# Epoch 29/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9780 - auc: 0.9973 - val_loss: 0.0940 - val_accuracy: 0.9707 - val_auc: 0.9946
# Epoch 30/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9780 - auc: 0.9974 - val_loss: 0.0919 - val_accuracy: 0.9707 - val_auc: 0.9948

# %%
model.evaluate(X_test, y_test)
# Out:
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9685 - auc: 0.9956
# [0.08876647055149078, 0.9684542417526245, 0.995639443397522]

# %% [markdown]
# #Prediction

# %%
y_pre=model.predict(X_test[:20])
new_y_pre = []
for i in y_pre:
  if i>0.5:
    new_y_pre.append(1)
  else:
    new_y_pre.append(0)
new_y_pre
# Out:
# [0, 1, 1, 0, 0, 0, 1, 1, 0, 1, 0, 0, 0, 1, 0, 0, 0, 0, 0, 1]

# %%
y_test[:20]
# Out:
# 2148    0
# 1124    1
# 170     1
# 3158    0
# 2229    0
# 1960    0
# 411     1
# 457     1
# 2881    0
# 602     1
# 2339    0
# 2490    0
# 2315    0
# 2985    0
# 2906    0
# 2421    0
# 2260    0
# 2877    0
# 2550    0
# 621     1
# Name: label, dtype: int64
